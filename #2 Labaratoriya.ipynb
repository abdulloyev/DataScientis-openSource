# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulloyev/DataScientis-openSource/blob/main/%232%20Labaratoriya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Abdulloyev Ulug'bek -- Labaratoriya N2 `Pandas kutubxonasini`**
# ---

# %% [markdown]
# ## Kerakli kutubxonalarni va DataFrameni chaqirib olamiz

# %%
import numpy as np
import pandas as pd

# DataFrame
from sklearn.datasets import fetch_california_housing

# %%
housing = fetch_california_housing()

hous_df = pd.DataFrame(housing.data, columns=housing.feature_names)
hous_df["target"] = housing.target

hous_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %% [markdown]
# ## **1).** Python ro‘yxatidan Pandas Series obyektini yarating.

# %%
list_ = [3, 3, 6, 1, 9, 4]

df = pd.Series(list_)
df
# Out:
# 0    3
# 1    3
# 2    6
# 3    1
# 4    9
# 5    4
# dtype: int64

# %%
type(df)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## **2).** Python lug‘atidan Pandas DataFrame obyektini yarating.

# %%
dictionary = {1: 'BMW', 2: 'Fort', 3: 'Gentira'}

df = pd.DataFrame(dictionary, index=[0], )
df
# Out:
#      1     2        3
# 0  BMW  Fort  Gentira

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## **3).** DataFramening oxirgi 5 qatorini ko‘rsating.

# %%
hous_df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  target
# ...

# %%
# dataFrame slice
hous_df[-5:]
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  target
# 20635    -121.09   0.781
# 20636    -121.21   0.771
# 20637    -121.22   0.923
# 20638    -121.32   0.847
# 20639    -121.24   0.894

# %% [markdown]
# ## **4).** DataFramening ustunlari nomlarini ko‘rsating.

# %%
hous_df.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude', 'target'],
#       dtype='object')

# %% [markdown]
# ## **5).** DataFramening ma’lumotlar turlarini (dtypes) ko‘rsating

# %%
# ustunlar typeni ko'rsatadi
hous_df.dtypes
# Out:
# MedInc        float64
# HouseAge      float64
# AveRooms      float64
# AveBedrms     float64
# Population    float64
# AveOccup      float64
# Latitude      float64
# Longitude     float64
# target        float64
# dtype: object

# %%
# dataframening typeni ko'rsatadi
type(hous_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## **6).** DataFramedan biror ustunni ajratib oling.

# %%
hous_df.sample(4)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 2100   1.6548      35.0  4.879418   1.093555      1676.0  3.484407     36.75
# 5378   3.2228      28.0  3.580042   1.114345      1161.0  2.413721     34.03
# 12164  2.5221       7.0  5.098592   1.087324       931.0  2.622535     33.74
# 9338   4.4375      40.0  5.735360   1.103039      3108.0  2.303929     37.99
#
#        Longitude  target
# 2100     -119.76   0.494
# 5378     -118.39   2.325
# 12164    -117.22   1.092
# 9338     -122.61   2.896

# %%
df_houseAge = hous_df["HouseAge"]
df_houseAge.sample(5)
# Out:
# 567      52.0
# 2404     33.0
# 2997     12.0
# 7191     42.0
# 15188    14.0
# Name: HouseAge, dtype: float64

# %% [markdown]
# ## **7).** DataFramedan bir nechta ustunlarni ajratib oling.

# %%
hous_df.sample(4)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 4737   4.4191      52.0  5.799065   0.981308       526.0  2.457944     34.05
# 1110   2.6147      11.0  6.268139   1.146688      1610.0  2.539432     39.82
# 3483   3.4812      35.0  4.508830   1.014349      3988.0  4.401766     34.30
# 19963  2.5875      22.0  5.537736   0.986792      1927.0  3.635849     36.23
#
#        Longitude  target
# 4737     -118.38   3.341
# 1110     -121.63   1.077
# 3483     -118.45   1.602
# 19963    -119.14   0.704

# %%
df = hous_df[["HouseAge", "AveRooms"]]
df.sample(5)
# Out:
#        HouseAge  AveRooms
# 3989       27.0  5.577465
# 18536      35.0  4.201571
# 2742        5.0  5.923990
# 16155      47.0  4.184783
# 8544       22.0  4.836237

# %% [markdown]
# ## **8).** DataFramedan shartga ko‘ra ma’lumotlarni filtrlang (masalan, qiymati 10 dan katta bo‘lgan qatorlarni ajratib oling).

# %%
df = hous_df[hous_df > 10]
df.sample(5)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 13984     NaN      33.0       NaN        NaN       347.0       NaN     34.75
# 6830      NaN      46.0       NaN        NaN       698.0       NaN     34.07
# 14658     NaN      31.0       NaN        NaN       422.0       NaN     32.79
# 9604      NaN      21.0       NaN        NaN      3967.0       NaN     37.31
# 15256     NaN      16.0       NaN        NaN      1433.0       NaN     33.04
#
#        Longitude  target
# 13984        NaN     NaN
# 6830         NaN     NaN
# 14658        NaN     NaN
# 9604         NaN     NaN
# 15256        NaN     NaN

# %% [markdown]
# ## **9).** DataFramedan biror qatorni indeks orqali ajratib oling

# %%
hous_df.head(1)
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127    1.02381       322.0  2.555556     37.88
#
#    Longitude  target
# 0    -122.23   4.526

# %%
# DataFramedan biror qatorni indeks orqali ajratib oling
df = pd.DataFrame(hous_df.iloc[0])
df.T
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127    1.02381       322.0  2.555556     37.88
#
#    Longitude  target
# 0    -122.23   4.526

# %% [markdown]
# ## **10).** DataFramega yangi ustun qo‘shing

# %%
hous_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
 hous_df['built'] = 2025 - hous_df['HouseAge']

# %%
hous_df.sample(5)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 17519  2.9853      28.0  3.242857   1.050000       366.0  2.614286     37.33
# 13740  4.6806      36.0  6.716012   1.090634       942.0  2.845921     34.03
# 4782   2.1046      35.0  3.981273   1.167291      2221.0  2.772784     34.03
# 4663   2.2937      42.0  1.986547   1.000000       582.0  2.609865     34.05
# 11223  4.2759      33.0  5.513120   0.973761       932.0  2.717201     33.81
#
#        Longitude  target   built
# 17519    -121.91   1.875  1997.0
# 13740    -117.19   1.524  1989.0
# 4782     -118.32   1.140  1990.0
# 4663     -118.31   3.500  1983.0
# 11223    -117.94   2.380  1992.0

# %% [markdown]
# ## **11).** DataFramening biror ustunidagi qiymatlarni o‘zgartiring.

# %%
hous_df.head(2)
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127    1.02381       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137    0.97188      2401.0  2.109842     37.86
#
#    Longitude  target   built
# 0    -122.23   4.526  1984.0
# 1    -122.22   3.585  2004.0

# %%
hous_df.at[0, 'HouseAge'] = 20
hous_df.at[1, 'HouseAge'] = 25

# %%
hous_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      20.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      25.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target   built
# 0    -122.23   4.526  1984.0
# 1    -122.22   3.585  2004.0
# 2    -122.24   3.521  1973.0
# 3    -122.25   3.413  1973.0
# 4    -122.25   3.422  1973.0

# %% [markdown]
# ## **12).** DataFramening indeksini o‘zgartiring.

# %%
df2 = hous_df.copy()
df2.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      20.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      25.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target   built
# 0    -122.23   4.526  1984.0
# 1    -122.22   3.585  2004.0
# 2    -122.24   3.521  1973.0
# 3    -122.25   3.413  1973.0
# 4    -122.25   3.422  1973.0

# %%
df2.index = df2['target']

# %%
df2.index[:10]
# Out:
# Index([4.526, 3.585, 3.521, 3.413, 3.422, 2.697, 2.992, 2.414, 2.267, 2.611], dtype='float64', name='target')

# %% [markdown]
# ## **13).** DataFrameni ustunlar bo‘yicha saralang.

# %%
hous_df.sort_index(axis=1, inplace=True)

# %%
hous_df.sample(5)
# Out:
#        AveBedrms  AveOccup  AveRooms  HouseAge  Latitude  Longitude  MedInc  \
# 487     1.095729  2.151694  5.558174      52.0     37.86    -122.26  2.9405
# 9450    1.294686  3.623188  5.229469      30.0     37.75    -119.55  3.5391
# 9435    1.332288  2.849530  6.633229      17.0     37.57    -120.02  2.7188
# 20347   0.966353  1.772544  4.890983       5.0     34.19    -119.00  4.2917
# 7080    1.098765  2.870370  5.989712      36.0     33.94    -118.00  5.1738
#
#        Population   built  target
# 487        1461.0  1973.0   2.895
# 9450       1500.0  1995.0   0.559
# 9435        909.0  2008.0   1.131
# 20347      1317.0  2020.0   2.279
# 7080       1395.0  1989.0   2.037

# %% [markdown]
# ## **14).** DataFramening har bir ustuni uchun o‘rtacha qiymatni hisoblang.

# %%
hous_df.mean()
# Out:
# AveBedrms        1.096675
# AveOccup         3.070655
# AveRooms         5.429000
# HouseAge        28.638663
# Latitude        35.631861
# Longitude     -119.569704
# MedInc           3.870671
# Population    1425.476744
# built         1996.360514
# target           2.068558
# dtype: float64

# %% [markdown]
# ## **15).** DataFramening har bir ustuni uchun maksimal qiymatni toping

# %%
hous_df.max()
# Out:
# AveBedrms        34.066667
# AveOccup       1243.333333
# AveRooms        141.909091
# HouseAge         52.000000
# Latitude         41.950000
# Longitude      -114.310000
# MedInc           15.000100
# Population    35682.000000
# built          2024.000000
# target            5.000010
# dtype: float64

# %% [markdown]
# ## **16).** DataFramening har bir ustuni uchun minimal qiymatni toping.

# %%
hous_df.min()
# Out:
# AveBedrms        0.333333
# AveOccup         0.692308
# AveRooms         0.846154
# HouseAge         1.000000
# Latitude        32.540000
# Longitude     -124.350000
# MedInc           0.499900
# Population       3.000000
# built         1973.000000
# target           0.149990
# dtype: float64

# %% [markdown]
# ## **17).** DataFramedagi NaN qiymatlarni ma’lum bir qiymat bilan to‘ldiring

# %%
hous_df.isnull().sum()
# Out:
# AveBedrms     0
# AveOccup      0
# AveRooms      0
# HouseAge      0
# Latitude      0
# Longitude     0
# MedInc        0
# Population    0
# built         0
# target        0
# dtype: int64

# %%
hous_df.fillna(0).head(4)
# Out:
#    AveBedrms  AveOccup  AveRooms  HouseAge  Latitude  Longitude  MedInc  \
# 0   1.023810  2.555556  6.984127      20.0     37.88    -122.23  8.3252
# 1   0.971880  2.109842  6.238137      25.0     37.86    -122.22  8.3014
# 2   1.073446  2.802260  8.288136      52.0     37.85    -122.24  7.2574
# 3   1.073059  2.547945  5.817352      52.0     37.85    -122.25  5.6431
#
#    Population   built  target
# 0       322.0  1984.0   4.526
# 1      2401.0  2004.0   3.585
# 2       496.0  1973.0   3.521
# 3       558.0  1973.0   3.413

# %% [markdown]
# ## **18).** DataFramedagi takrorlanadigan qatorlarni o‘chiring.

# %%
hous_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   AveBedrms   20640 non-null  float64
#  1   AveOccup    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   HouseAge    20640 non-null  float64
#  4   Latitude    20640 non-null  float64
#  5   Longitude   20640 non-null  float64
#  6   MedInc      20640 non-null  float64
#  7   Population  20640 non-null  float64
#  8   built       20640 non-null  float64
#  9   target      20640 non-null  float64
# dtypes: float64(10)
# memory usage: 1.6 MB

# %%
df2 = hous_df.drop_duplicates(keep='first')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   AveBedrms   20640 non-null  float64
#  1   AveOccup    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   HouseAge    20640 non-null  float64
#  4   Latitude    20640 non-null  float64
#  5   Longitude   20640 non-null  float64
#  6   MedInc      20640 non-null  float64
#  7   Population  20640 non-null  float64
#  8   built       20640 non-null  float64
#  9   target      20640 non-null  float64
# dtypes: float64(10)
# memory usage: 1.6 MB

# %% [markdown]
# ## **19).** DataFramedagi ustunlarning nomlarini o‘zgartiring.

# %%
  df2.head(3)
# Out:
#    AveBedrms  AveOccup  AveRooms  HouseAge  Latitude  Longitude  MedInc  \
# 0   1.023810  2.555556  6.984127      20.0     37.88    -122.23  8.3252
# 1   0.971880  2.109842  6.238137      25.0     37.86    -122.22  8.3014
# 2   1.073446  2.802260  8.288136      52.0     37.85    -122.24  7.2574
#
#    Population   built  target
# 0       322.0  1984.0   4.526
# 1      2401.0  2004.0   3.585
# 2       496.0  1973.0   3.521

# %%
df2.rename(columns={'built': 'qurilgan'}, inplace=True)
df2.sample(5)
# Out:
#        AveBedrms  AveOccup  AveRooms  HouseAge  Latitude  Longitude  MedInc  \
# 10127   0.994226  3.199769  7.043880      17.0     33.93    -117.88  7.6486
# 6867    1.026455  3.449735  4.037037      25.0     34.06    -118.12  3.1892
# 7928    0.944444  3.157407  4.884259      22.0     33.85    -118.08  6.0000
# 1611    1.076923  1.524038  5.298077      17.0     37.86    -122.07  3.5893
# 1829    1.105528  2.839196  5.623116      22.0     37.92    -122.32  3.3594
#
#        Population  qurilgan  target
# 10127      2771.0    2008.0   3.067
# 6867       1304.0    2000.0   2.147
# 7928        682.0    2003.0   1.913
# 1611        317.0    2008.0   2.063
# 1829        565.0    2003.0   1.869

# %% [markdown]
# ## **20).** DataFramedagi ma’lumotlar turlarini o‘zgartiring (masalan, sonlarni matnga aylantiring).

# %%
df2.dtypes
# Out:
# AveBedrms     float64
# AveOccup      float64
# AveRooms      float64
# HouseAge      float64
# Latitude      float64
# Longitude     float64
# MedInc        float64
# Population    float64
# qurilgan      float64
# target        float64
# dtype: object

# %%
df2['qurilgan'] = df2['qurilgan'].astype(str)
df2.dtypes
# Out:
# AveBedrms     float64
# AveOccup      float64
# AveRooms      float64
# HouseAge      float64
# Latitude      float64
# Longitude     float64
# MedInc        float64
# Population    float64
# qurilgan       object
# target        float64
# dtype: object

# %% [markdown]
# ## **21).** Ikki DataFrameni vertikal ravishda birlashtiring.

# %%
df1 = pd.DataFrame([3, 6, 3, 2, 8])
df2 = pd.DataFrame([8, 4, 9, 2, 12])

# ignore_index=1 index ni qaytadan tartiblaydi
df = pd.concat([df1, df2], ignore_index=1)
df
# Out:
#     0
# 0   3
# 1   6
# 2   3
# 3   2
# 4   8
# 5   8
# 6   4
# 7   9
# 8   2
# 9  12

# %% [markdown]
# ## **22).** Ikki DataFrameni gorizontal ravishda birlashtiring.

# %%
df =  pd.concat([df1, df2], ignore_index=True, axis=1)
df
# Out:
#    0   1
# 0  3   8
# 1  6   4
# 2  3   9
# 3  2   2
# 4  8  12

# %% [markdown]
# ## **23).** DataFramedan ikki ustunni grafik sifatida chizing.

# %%
import matplotlib.pyplot as plt

# %%
hous_df.head(2)
# Out:
#    AveBedrms  AveOccup  AveRooms  HouseAge  Latitude  Longitude  MedInc  \
# 0    1.02381  2.555556  6.984127      20.0     37.88    -122.23  8.3252
# 1    0.97188  2.109842  6.238137      25.0     37.86    -122.22  8.3014
#
#    Population   built  target
# 0       322.0  1984.0   4.526
# 1      2401.0  2004.0   3.585

# %%
plt.scatter(hous_df['target'], hous_df['Population'], color='red')

plt.xlabel("Population")
plt.ylabel("target")
plt.title("Population vs target")
plt.show()

# %% [markdown]
# ## **24).** Pandas yordamida mahsulotlar haqidagi ma’lumotlar tuzilib, ular bilan manipulyatsiya qilish

# %%
df = hous_df.copy()
df.head(3)
# Out:
#    AveBedrms  AveOccup  AveRooms  HouseAge  Latitude  Longitude  MedInc  \
# 0   1.023810  2.555556  6.984127      20.0     37.88    -122.23  8.3252
# 1   0.971880  2.109842  6.238137      25.0     37.86    -122.22  8.3014
# 2   1.073446  2.802260  8.288136      52.0     37.85    -122.24  7.2574
#
#    Population   built  target
# 0       322.0  1984.0   4.526
# 1      2401.0  2004.0   3.585
# 2       496.0  1973.0   3.521

# %% [markdown]
# ### *

# %%
df['*'] = df['Latitude'] * df['Longitude']
df.head(3)
# Out:
#    AveBedrms  AveOccup  AveRooms  HouseAge  Latitude  Longitude  MedInc  \
# 0   1.023810  2.555556  6.984127      20.0     37.88    -122.23  8.3252
# 1   0.971880  2.109842  6.238137      25.0     37.86    -122.22  8.3014
# 2   1.073446  2.802260  8.288136      52.0     37.85    -122.24  7.2574
#
#    Population   built  target          *
# 0       322.0  1984.0   4.526 -4630.0724
# 1      2401.0  2004.0   3.585 -4627.2492
# 2       496.0  1973.0   3.521 -4626.7840

# %% [markdown]
# ### ===

# %%
x = df[df['built'] == 2005.0]
x.head(10)
# Out:
#      AveBedrms  AveOccup  AveRooms  HouseAge  Latitude  Longitude  MedInc  \
# 74    1.210526  2.180451  6.278195      20.0     37.81    -122.29  2.4830
# 195   1.152367  2.454142  3.510355      20.0     37.80    -122.26  1.6929
# 575   1.119632  1.788344  3.546012      20.0     37.75    -122.28  3.1972
# 610   1.021250  2.165000  5.370000      20.0     37.69    -122.09  4.8036
# 700   0.806452  2.677419  6.451613      20.0     37.69    -122.03  6.5000
# 803   1.046512  1.993023  3.848837      20.0     37.64    -122.06  3.5541
# 861   1.057436  2.132308  4.231795      20.0     37.58    -121.98  3.6832
# 881   1.047773  2.662348  5.232389      20.0     37.56    -121.99  4.3393
# 936   1.007547  3.326415  6.116038      20.0     37.54    -122.06  5.0838
# 961   0.976923  3.196154  6.938462      20.0     37.68    -121.91  6.1770
#
#      Population   built  target          *
# 74        290.0  2005.0   1.375 -4623.7849
# 195      1659.0  2005.0   1.150 -4621.4280
# ...

# %% [markdown]
# ### sort

# %%
df.sort_values(by="built", ascending=False) # yuqoridan pastga qarab saralash
df.sample(5)
# Out:
#        AveBedrms  AveOccup  AveRooms  HouseAge  Latitude  Longitude  MedInc  \
# 9174    1.043372  2.769231  4.481997      21.0     34.39    -118.52  3.6625
# 4984    1.033613  3.584034  5.445378      52.0     34.00    -118.30  3.0500
# 3559    1.096610  2.591525  5.489831      26.0     34.24    -118.58  3.2426
# 11467   1.135652  1.653913  5.486957      14.0     33.66    -117.99  3.0625
# 15785   1.282916  1.568009  3.769314       3.0     37.78    -122.39  4.7105
#
#        Population   built  target          *
# 9174       3384.0  2004.0   2.281 -4075.9028
# 4984        853.0  1973.0   1.116 -4022.2000
# 3559       1529.0  1999.0   2.369 -4060.1792
# 11467       951.0  2011.0   2.688 -3971.5434
# 15785      1441.0  2022.0   2.750 -4623.8942

# %% [markdown]
# ## **25).** DataFrame’dan ma’lumotlarni faylga yozish (excel, csv)

# %%
df.to_csv("uy_vazasi.csv", index=False) # .csv farmatda saqlash

# %%
df.to_json("uy_vazasi.json", index=False)
